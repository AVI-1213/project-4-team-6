# %%
from time import sleep
from math import ceil
import os
from random import randint
from requests import HTTPError
import pandas as pd
from queries import get_coordinates, get_property_list, get_property_details

# %%
# Load the CSV file into a DataFrame
# Load the CSV file into a DataFrame
path = pd.read_csv('neighborhoods.csv')

# Set the index using all columns except 'zips'
neighborhoods_df = path.set_index(['neighborhood', 'neighborhood_ascii', 'lat', 'lng', 'city_name', 'city_id', 'state_name', 'state_id', 'source', 'timezone', 'county_fips', 'county_name', 'id'])

# Split the 'zips' column into separate rows
neighborhoods_df = neighborhoods_df['zips'].str.split(' ', expand=True).stack().reset_index(level=1, drop=True).reset_index(name='zip_code')


neighborhoods_df
# Out:
#                    neighborhood       lat       lng   city_name     city_id  \
# 0     Atlanta University Center  33.74947 -84.41125     Atlanta  1840013660
# 1                  Hunter Hills  33.75872 -84.43123     Atlanta  1840013660
# 2                      Bankhead  33.76901 -84.42452     Atlanta  1840013660
# 3                      Bankhead  33.76901 -84.42452     Atlanta  1840013660
# 4                English Avenue  33.77070 -84.41099     Atlanta  1840013660
# ...                         ...       ...       ...         ...         ...
# 5455                   Buckhead  33.83955 -84.37937     Atlanta  1840013660
# 5456              Blair Village  33.65761 -84.37020     Atlanta  1840013660
# 5457                 West Tampa  27.95335 -82.48926       Tampa  1840015982
# 5458                Terra Cotta  38.95372 -76.99831  Washington  1840006060
# 5459                 Lemon City  25.83037 -80.19283       Miami  1840015149
#
#                 state_name state_id   source          timezone  county_fips  \
# 0                  Georgia       GA  polygon  America/New_York        13121
# 1                  Georgia       GA  polygon  America/New_York        13121
# 2                  Georgia       GA  polygon  America/New_York        13121
# 3                  Georgia       GA  polygon  America/New_York        13121
# 4                  Georgia       GA  polygon  America/New_York        13121
# ...                    ...      ...      ...               ...          ...
# 5455               Georgia       GA    point  America/New_York        13121
# 5456               Georgia       GA    point  America/New_York        13121
# 5457               Florida       FL    point  America/New_York        12057
# 5458  District of Columbia       DC    point  America/New_York        11001
# 5459               Florida       FL    point  America/New_York        12086
#
#                county_name               id  level_12 zip_code
# 0                   Fulton  184001366011100         0    30314
# 1                   Fulton  184001366011101         0    30314
# 2                   Fulton  184001366011102         0    30318
# 3                   Fulton  184001366011102         1    30314
# 4                   Fulton  184001366011103         0    30318
# ...                    ...              ...       ...      ...
# 5455                Fulton  184001366014125         0    30305
# 5456                Fulton  184001366014126         0    30354
# 5457          Hillsborough  184001598214105         0    33607
# 5458  District of Columbia  184000606014149         0    20011
# 5459            Miami-Dade  184001514914108         0    33137
#
# [5460 rows x 14 columns]

# %%
selected_neighbor_df = neighborhoods_df[['neighborhood', 'zip_code']]
selected_neighbor_df
# Out:
#                    neighborhood zip_code
# 0     Atlanta University Center    30314
# 1                  Hunter Hills    30314
# 2                      Bankhead    30318
# 3                      Bankhead    30314
# 4                English Avenue    30318
# ...                         ...      ...
# 5455                   Buckhead    30305
# 5456              Blair Village    30354
# 5457                 West Tampa    33607
# 5458                Terra Cotta    20011
# 5459                 Lemon City    33137
#
# [5460 rows x 2 columns]

# %%
selected_neighbor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5460 entries, 0 to 5459
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   neighborhood  5460 non-null   object
#  1   zip_code      5460 non-null   object
# dtypes: object(2)
# memory usage: 85.4+ KB

# %%
# # Load the CSV file into a DataFrame
# rank_path = pd.read_csv('city_rank.csv')

# # Inspect the columns
# print(rank_path.columns)

# # If 'zips' exists under a different name, update it here
# # Assuming 'zip_codes' is the correct column name
# if 'zip_codes' in rank_path.columns:
#     # Set the index using all columns except the correct zips column
#     city_rank_df = rank_path.set_index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
#                                         'county_name', 'lat', 'lng', 'population', 'density', 'source',
#                                         'military', 'incorporated', 'timezone', 'ranking', 'zip_codes', 'id'])

#     # Split the 'zip_codes' column into separate rows
#     city_rank_df = city_rank_df['zip_codes'].str.split(' ', expand=True).stack().reset_index(level=1, drop=True).reset_index(name='ZIP Code')

#     print(city_rank_df)
# else:
#     print("Column 'zips' or equivalent not found in the dataset.")

# %%
# Load the CSV file into a DataFrame
rank_path = pd.read_csv('city_rank.csv')

# Set the index using all columns except 'zips'
city_rank_df = rank_path.set_index(['city', 'city_ascii', 'state_id', 'state_name', 'county_fips',
       'county_name', 'lat', 'lng', 'population', 'density', 'source',
       'military', 'incorporated', 'timezone', 'ranking', 'id'])

# Split the 'zips' column into separate rows
city_rank_df = city_rank_df['zips'].str.split(' ', expand=True).stack().reset_index(level=1, drop=True).reset_index(name='zip_code')

# Display the resulting DataFrame
city_rank_df
# Out:
#                  city state_id    state_name  county_fips county_name  \
# 0            New York       NY      New York        36081      Queens
# 1            New York       NY      New York        36081      Queens
# 2            New York       NY      New York        36081      Queens
# 3            New York       NY      New York        36081      Queens
# 4            New York       NY      New York        36081      Queens
# ...               ...      ...           ...          ...         ...
# 48184          Kohatk       AZ       Arizona         4021       Pinal
# 48185       Ironville       PA  Pennsylvania        42013       Blair
# 48186         Newkirk       NM    New Mexico        35019   Guadalupe
# 48187  Falcon Village       TX         Texas        48427       Starr
# 48188     Millerstown       PA  Pennsylvania        42013       Blair
#
#            lat       lng  population  density source  military  incorporated  \
# 0      40.6943  -73.9249    18908608  11080.3  shape     False          True
# 1      40.6943  -73.9249    18908608  11080.3  shape     False          True
# 2      40.6943  -73.9249    18908608  11080.3  shape     False          True
# 3      40.6943  -73.9249    18908608  11080.3  shape     False          True
# 4      40.6943  -73.9249    18908608  11080.3  shape     False          True
# ...        ...       ...         ...      ...    ...       ...           ...
# 48184  32.5781 -112.0032           0     77.3  shape     False         False
# 48185  40.6586  -78.2155           0     59.2  shape     False         False
# 48186  35.0635 -104.2715           0      0.0  shape     False         False
# 48187  26.5652  -99.1341           0     38.9  shape     False         False
# 48188  40.2771  -78.3029           0     28.0  shape     False         False
#
#                timezone  ranking          id  level_15 zip_code
# 0      America/New_York        1  1840034016         0    11229
# 1      America/New_York        1  1840034016         1    11228
# 2      America/New_York        1  1840034016         2    11226
# 3      America/New_York        1  1840034016         3    11225
# 4      America/New_York        1  1840034016         4    11224
# ...                 ...      ...         ...       ...      ...
# 48184   America/Phoenix        3  1840022983         0    85634
# 48185  America/New_York        3  1840152922         0    16686
# 48186    America/Denver        3  1840024978         0    88417
# 48187   America/Chicago        3  1840018314         0    78545
# 48188  America/New_York        3  1840153020         0    16662
#
# [48189 rows x 17 columns]

# %%
selected_rank_df = city_rank_df[['ranking', 'zip_code']]
selected_rank_df
# Out:
#        ranking zip_code
# 0            1    11229
# 1            1    11228
# 2            1    11226
# 3            1    11225
# 4            1    11224
# ...        ...      ...
# 48184        3    85634
# 48185        3    16686
# 48186        3    88417
# 48187        3    78545
# 48188        3    16662
#
# [48189 rows x 2 columns]

# %%
selected_rank_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48189 entries, 0 to 48188
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   ranking   48189 non-null  int64
#  1   zip_code  48189 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 753.1+ KB

# %%
realtor_path = pd.read_csv('realtor_data.csv')
realtor_path
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state  zip_code  house_size prev_sold_date
# 0          Adjuntas  Puerto Rico     601.0       920.0            NaN
# 1          Adjuntas  Puerto Rico     601.0      1527.0            NaN
# 2        Juana Diaz  Puerto Rico     795.0       748.0            NaN
# 3             Ponce  Puerto Rico     731.0      1800.0            NaN
# 4          Mayaguez  Puerto Rico     680.0         NaN            NaN
# ...             ...          ...       ...         ...            ...
# 2226377    Richland   Washington   99354.0      3600.0     2022-03-25
# 2226378    Richland   Washington   99354.0      1616.0     2022-03-25
# 2226379    Richland   Washington   99354.0      3200.0     2022-03-24
# 2226380    Richland   Washington   99354.0       933.0     2022-03-24
# 2226381    Richland   Washington   99354.0      3615.0     2022-03-23
#
# [2226382 rows x 12 columns]

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        float64
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(8), object(4)
# memory usage: 203.8+ MB

# %%
realtor_path['zip_code'] = realtor_path['zip_code'].astype(str).str.zfill(5)

# %%
realtor_path['zip_code'] = realtor_path['zip_code'].str.replace('.0', '', regex=False)

# %%
realtor_path
# Out:
#          brokered_by    status     price  bed  bath  acre_lot     street  \
# 0           103378.0  for_sale  105000.0  3.0   2.0      0.12  1962661.0
# 1            52707.0  for_sale   80000.0  4.0   2.0      0.08  1902874.0
# 2           103379.0  for_sale   67000.0  2.0   1.0      0.15  1404990.0
# 3            31239.0  for_sale  145000.0  4.0   2.0      0.10  1947675.0
# 4            34632.0  for_sale   65000.0  6.0   2.0      0.05   331151.0
# ...              ...       ...       ...  ...   ...       ...        ...
# 2226377      23009.0      sold  359900.0  4.0   2.0      0.33   353094.0
# 2226378      18208.0      sold  350000.0  3.0   2.0      0.10  1062149.0
# 2226379      76856.0      sold  440000.0  6.0   3.0      0.50   405677.0
# 2226380      53618.0      sold  179900.0  2.0   1.0      0.09   761379.0
# 2226381     108243.0      sold  580000.0  5.0   3.0      0.31   307704.0
#
#                city        state zip_code  house_size prev_sold_date
# 0          Adjuntas  Puerto Rico    00601       920.0            NaN
# 1          Adjuntas  Puerto Rico    00601      1527.0            NaN
# 2        Juana Diaz  Puerto Rico    00795       748.0            NaN
# 3             Ponce  Puerto Rico    00731      1800.0            NaN
# 4          Mayaguez  Puerto Rico    00680         NaN            NaN
# ...             ...          ...      ...         ...            ...
# 2226377    Richland   Washington    99354      3600.0     2022-03-25
# 2226378    Richland   Washington    99354      1616.0     2022-03-25
# 2226379    Richland   Washington    99354      3200.0     2022-03-24
# 2226380    Richland   Washington    99354       933.0     2022-03-24
# 2226381    Richland   Washington    99354      3615.0     2022-03-23
#
# [2226382 rows x 12 columns]

# %%
realtor_path.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2226382 entries, 0 to 2226381
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   brokered_by     float64
#  1   status          object
#  2   price           float64
#  3   bed             float64
#  4   bath            float64
#  5   acre_lot        float64
#  6   street          float64
#  7   city            object
#  8   state           object
#  9   zip_code        object
#  10  house_size      float64
#  11  prev_sold_date  object
# dtypes: float64(7), object(5)
# memory usage: 203.8+ MB

# %%
# Now merge the DataFrames
merged_df_1 = pd.merge(selected_neighbor_df, realtor_path, on='zip_code')

# Display the merged DataFrame
merged_df_1
# Out:
#                       neighborhood zip_code  brokered_by    status      price  \
# 0        Atlanta University Center    30314      21417.0  for_sale   549900.0
# 1        Atlanta University Center    30314       6916.0  for_sale   125000.0
# 2        Atlanta University Center    30314      22611.0  for_sale   180000.0
# 3        Atlanta University Center    30314      78186.0  for_sale    69900.0
# 4        Atlanta University Center    30314      78186.0  for_sale    69900.0
# ...                            ...      ...          ...       ...        ...
# 1174329       Southwest Waterfront    20024      16829.0      sold  1249000.0
# 1174330       Southwest Waterfront    20024      16829.0      sold   454900.0
# 1174331       Southwest Waterfront    20024      22611.0      sold   499000.0
# 1174332       Southwest Waterfront    20024      59064.0      sold  1190000.0
# 1174333       Southwest Waterfront    20024      86393.0      sold   660000.0
#
#          bed  bath  acre_lot     street        city                 state  \
# 0        4.0   4.0      0.10  1729649.0     Atlanta               Georgia
# 1        NaN   NaN      0.08  1423689.0     Atlanta               Georgia
# 2        2.0   1.0      0.15   348737.0     Atlanta               Georgia
# 3        NaN   NaN      0.07  1743414.0     Atlanta               Georgia
# 4        NaN   NaN      0.07  1743413.0     Atlanta               Georgia
# ...      ...   ...       ...        ...         ...                   ...
# 1174329  4.0   4.0      0.03  1592848.0  Washington  District of Columbia
# 1174330  1.0   1.0       NaN  1569139.0  Washington  District of Columbia
# 1174331  2.0   2.0       NaN   244513.0  Washington  District of Columbia
# 1174332  4.0   4.0      0.03  1455794.0  Washington  District of Columbia
# 1174333  2.0   2.0       NaN   677014.0  Washington  District of Columbia
#
#          house_size prev_sold_date
# 0            1870.0     2020-12-30
# 1               NaN     2020-07-02
# 2            1158.0            NaN
# 3               NaN            NaN
# 4               NaN     2022-06-01
# ...             ...            ...
# 1174329      2440.0     2021-12-08
# 1174330      1000.0     2021-12-10
# 1174331      1194.0     2021-12-27
# 1174332      2440.0     2021-12-27
# 1174333      1344.0     2021-12-28
#
# [1174334 rows x 13 columns]

# %%
merged_df = pd.merge(selected_rank_df, merged_df_1, on='zip_code')
merged_df
# Out:
#          ranking zip_code     neighborhood  brokered_by    status     price  \
# 0              1    11229  Gerritsen Beach      23592.0  for_sale  999000.0
# 1              1    11229  Gerritsen Beach      84536.0  for_sale  659000.0
# 2              1    11229  Gerritsen Beach      81944.0  for_sale  938000.0
# 3              1    11229  Gerritsen Beach      81286.0  for_sale  748000.0
# 4              1    11229  Gerritsen Beach      76342.0  for_sale  538000.0
# ...          ...      ...              ...          ...       ...       ...
# 1638125        3    85339           Laveen      53339.0      sold  440000.0
# 1638126        3    85339           Laveen     107243.0      sold  339000.0
# 1638127        3    85339           Laveen      66216.0      sold  439900.0
# 1638128        3    85339           Laveen      30687.0      sold  395000.0
# 1638129        3    85339           Laveen      57866.0      sold  155000.0
#
#          bed  bath  acre_lot     street           city     state  house_size  \
# 0        2.0   1.0       NaN  1450948.0  New York City  New York       840.0
# 1        2.0   2.0      0.04  1808463.0       Brooklyn  New York       980.0
# 2        3.0   3.0      0.05   384285.0       Brooklyn  New York      2352.0
# 3        3.0   1.0      0.04   628929.0       Brooklyn  New York      1224.0
# 4        3.0   1.0      0.04  1053053.0       Brooklyn  New York      1000.0
# ...      ...   ...       ...        ...            ...       ...         ...
# 1638125  3.0   2.0      0.18  1421021.0         Laveen   Arizona      1996.0
# 1638126  3.0   2.0      0.14  1302003.0         Laveen   Arizona      1552.0
# 1638127  5.0   3.0      0.15  1360935.0         Laveen   Arizona      2462.0
# 1638128  3.0   2.0      0.13  1476747.0         Laveen   Arizona      1864.0
# 1638129  NaN   NaN      2.01  1954651.0         Laveen   Arizona         NaN
#
#         prev_sold_date
# 0                  NaN
# 1           2014-10-01
# 2           2021-07-07
# 3           2011-01-24
# 4           1996-12-16
# ...                ...
# 1638125     2022-01-19
# 1638126     2022-01-19
# 1638127     2022-01-06
# 1638128     2022-01-06
# 1638129     2022-02-23
#
# [1638130 rows x 14 columns]

# %%
merged_df.isnull().sum()
# Out:
# ranking                0
# zip_code               0
# neighborhood           0
# brokered_by         1438
# status                 0
# price                111
# bed               120206
# bath              110460
# acre_lot          453791
# street             12563
# city                  35
# state                  0
# house_size        226029
# prev_sold_date    361273
# dtype: int64

# %%
merged_df['prev_sold_date'].fillna(value='other', inplace=True)

# %%
merged_df.isnull().sum()
# Out:
# ranking                0
# zip_code               0
# neighborhood           0
# brokered_by         1438
# status                 0
# price                111
# bed               120206
# bath              110460
# acre_lot          453791
# street             12563
# city                  35
# state                  0
# house_size        226029
# prev_sold_date         0
# dtype: int64

# %%
cleaned_df = merged_df.dropna()
cleaned_df
# Out:
#          ranking zip_code     neighborhood  brokered_by    status     price  \
# 1              1    11229  Gerritsen Beach      84536.0  for_sale  659000.0
# 2              1    11229  Gerritsen Beach      81944.0  for_sale  938000.0
# 3              1    11229  Gerritsen Beach      81286.0  for_sale  748000.0
# 4              1    11229  Gerritsen Beach      76342.0  for_sale  538000.0
# 9              1    11229  Gerritsen Beach      34944.0  for_sale  678000.0
# ...          ...      ...              ...          ...       ...       ...
# 1638124        3    85339           Laveen      84534.0      sold  458000.0
# 1638125        3    85339           Laveen      53339.0      sold  440000.0
# 1638126        3    85339           Laveen     107243.0      sold  339000.0
# 1638127        3    85339           Laveen      66216.0      sold  439900.0
# 1638128        3    85339           Laveen      30687.0      sold  395000.0
#
#          bed  bath  acre_lot     street      city     state  house_size  \
# 1        2.0   2.0      0.04  1808463.0  Brooklyn  New York       980.0
# 2        3.0   3.0      0.05   384285.0  Brooklyn  New York      2352.0
# 3        3.0   1.0      0.04   628929.0  Brooklyn  New York      1224.0
# 4        3.0   1.0      0.04  1053053.0  Brooklyn  New York      1000.0
# 9        3.0   2.0      0.04  1567742.0  Brooklyn  New York      1216.0
# ...      ...   ...       ...        ...       ...       ...         ...
# 1638124  4.0   3.0      0.23  1675725.0    Laveen   Arizona      2056.0
# 1638125  3.0   2.0      0.18  1421021.0    Laveen   Arizona      1996.0
# 1638126  3.0   2.0      0.14  1302003.0    Laveen   Arizona      1552.0
# 1638127  5.0   3.0      0.15  1360935.0    Laveen   Arizona      2462.0
# 1638128  3.0   2.0      0.13  1476747.0    Laveen   Arizona      1864.0
#
#         prev_sold_date
# 1           2014-10-01
# 2           2021-07-07
# 3           2011-01-24
# 4           1996-12-16
# 9           2011-07-26
# ...                ...
# 1638124     2022-01-19
# 1638125     2022-01-19
# 1638126     2022-01-19
# 1638127     2022-01-06
# 1638128     2022-01-06
#
# [1012403 rows x 14 columns]

# %%
cleaned_df.describe()
# Out:
#             ranking   brokered_by         price           bed          bath  \
# count  1.012403e+06  1.012403e+06  1.012403e+06  1.012403e+06  1.012403e+06
# mean   1.433617e+00  5.333029e+04  7.337206e+05  3.376095e+00  2.575950e+00
# std    7.651784e-01  3.093934e+04  1.527879e+06  1.624061e+00  1.563390e+00
# min    1.000000e+00  2.000000e+00  9.500000e+02  1.000000e+00  1.000000e+00
# 25%    1.000000e+00  2.418600e+04  2.800000e+05  3.000000e+00  2.000000e+00
# 50%    1.000000e+00  5.292800e+04  4.690000e+05  3.000000e+00  2.000000e+00
# 75%    2.000000e+00  7.922100e+04  7.820000e+05  4.000000e+00  3.000000e+00
# max    4.000000e+00  1.101400e+05  5.150000e+08  1.080000e+02  1.750000e+02
#
#            acre_lot        street    house_size
# count  1.012403e+06  1.012403e+06  1.012403e+06
# mean   2.384008e+01  9.928176e+05  2.005633e+03
# std    5.334405e+02  5.215439e+05  4.043389e+03
# min    0.000000e+00  5.681000e+03  1.000000e+02
# 25%    6.000000e-02  5.428870e+05  1.238000e+03
# 50%    1.300000e-01  1.046816e+06  1.670000e+03
# 75%    2.000000e-01  1.426027e+06  2.346000e+03
# max    1.000000e+05  1.999512e+06  1.560780e+06

# %%
cleaned_df.isnull().sum()
# Out:
# ranking           0
# zip_code          0
# neighborhood      0
# brokered_by       0
# status            0
# price             0
# bed               0
# bath              0
# acre_lot          0
# street            0
# city              0
# state             0
# house_size        0
# prev_sold_date    0
# dtype: int64

# %%
cleaned_df.duplicated().sum()
# Out:
# 90844

# %%
duplicates = cleaned_df.duplicated()

# Display only the rows that are duplicates
duplicate_rows = cleaned_df[duplicates]

duplicate_rows
# Out:
#          ranking zip_code     neighborhood  brokered_by    status     price  \
# 1615           1    11229  Gerritsen Beach      84536.0  for_sale  659000.0
# 1616           1    11229  Gerritsen Beach      81944.0  for_sale  938000.0
# 1617           1    11229  Gerritsen Beach      81286.0  for_sale  748000.0
# 1618           1    11229  Gerritsen Beach      76342.0  for_sale  538000.0
# 1623           1    11229  Gerritsen Beach      34944.0  for_sale  678000.0
# ...          ...      ...              ...          ...       ...       ...
# 1638124        3    85339           Laveen      84534.0      sold  458000.0
# 1638125        3    85339           Laveen      53339.0      sold  440000.0
# 1638126        3    85339           Laveen     107243.0      sold  339000.0
# 1638127        3    85339           Laveen      66216.0      sold  439900.0
# 1638128        3    85339           Laveen      30687.0      sold  395000.0
#
#          bed  bath  acre_lot     street      city     state  house_size  \
# 1615     2.0   2.0      0.04  1808463.0  Brooklyn  New York       980.0
# 1616     3.0   3.0      0.05   384285.0  Brooklyn  New York      2352.0
# 1617     3.0   1.0      0.04   628929.0  Brooklyn  New York      1224.0
# 1618     3.0   1.0      0.04  1053053.0  Brooklyn  New York      1000.0
# 1623     3.0   2.0      0.04  1567742.0  Brooklyn  New York      1216.0
# ...      ...   ...       ...        ...       ...       ...         ...
# 1638124  4.0   3.0      0.23  1675725.0    Laveen   Arizona      2056.0
# 1638125  3.0   2.0      0.18  1421021.0    Laveen   Arizona      1996.0
# 1638126  3.0   2.0      0.14  1302003.0    Laveen   Arizona      1552.0
# 1638127  5.0   3.0      0.15  1360935.0    Laveen   Arizona      2462.0
# 1638128  3.0   2.0      0.13  1476747.0    Laveen   Arizona      1864.0
#
#         prev_sold_date
# 1615        2014-10-01
# 1616        2021-07-07
# 1617        2011-01-24
# 1618        1996-12-16
# 1623        2011-07-26
# ...                ...
# 1638124     2022-01-19
# 1638125     2022-01-19
# 1638126     2022-01-19
# 1638127     2022-01-06
# 1638128     2022-01-06
#
# [90844 rows x 14 columns]

# %%
# Drop duplicate rows
cleaned_df_no_duplicates = cleaned_df.drop_duplicates()

# Display the DataFrame without duplicates
cleaned_df_no_duplicates
# Out:
#          ranking zip_code     neighborhood  brokered_by    status     price  \
# 1              1    11229  Gerritsen Beach      84536.0  for_sale  659000.0
# 2              1    11229  Gerritsen Beach      81944.0  for_sale  938000.0
# 3              1    11229  Gerritsen Beach      81286.0  for_sale  748000.0
# 4              1    11229  Gerritsen Beach      76342.0  for_sale  538000.0
# 9              1    11229  Gerritsen Beach      34944.0  for_sale  678000.0
# ...          ...      ...              ...          ...       ...       ...
# 1637722        4    85339           Laveen      84534.0      sold  458000.0
# 1637723        4    85339           Laveen      53339.0      sold  440000.0
# 1637724        4    85339           Laveen     107243.0      sold  339000.0
# 1637725        4    85339           Laveen      66216.0      sold  439900.0
# 1637726        4    85339           Laveen      30687.0      sold  395000.0
#
#          bed  bath  acre_lot     street      city     state  house_size  \
# 1        2.0   2.0      0.04  1808463.0  Brooklyn  New York       980.0
# 2        3.0   3.0      0.05   384285.0  Brooklyn  New York      2352.0
# 3        3.0   1.0      0.04   628929.0  Brooklyn  New York      1224.0
# 4        3.0   1.0      0.04  1053053.0  Brooklyn  New York      1000.0
# 9        3.0   2.0      0.04  1567742.0  Brooklyn  New York      1216.0
# ...      ...   ...       ...        ...       ...       ...         ...
# 1637722  4.0   3.0      0.23  1675725.0    Laveen   Arizona      2056.0
# 1637723  3.0   2.0      0.18  1421021.0    Laveen   Arizona      1996.0
# 1637724  3.0   2.0      0.14  1302003.0    Laveen   Arizona      1552.0
# 1637725  5.0   3.0      0.15  1360935.0    Laveen   Arizona      2462.0
# 1637726  3.0   2.0      0.13  1476747.0    Laveen   Arizona      1864.0
#
#         prev_sold_date
# 1           2014-10-01
# 2           2021-07-07
# 3           2011-01-24
# 4           1996-12-16
# 9           2011-07-26
# ...                ...
# 1637722     2022-01-19
# 1637723     2022-01-19
# 1637724     2022-01-19
# 1637725     2022-01-06
# 1637726     2022-01-06
#
# [921559 rows x 14 columns]

# %%
cleaned_df_no_duplicates = cleaned_df_no_duplicates[['state', 'city', 'street', 'neighborhood', 'bed', 'bath', 'acre_lot', 'house_size', 'price', 'ranking',	'zip_code', 'brokered_by', 'status', 'prev_sold_date']]
cleaned_df_no_duplicates.head(20)
# Out:
#        state      city     street     neighborhood  bed  bath  acre_lot  \
# 1   New York  Brooklyn  1808463.0  Gerritsen Beach  2.0   2.0      0.04
# 2   New York  Brooklyn   384285.0  Gerritsen Beach  3.0   3.0      0.05
# 3   New York  Brooklyn   628929.0  Gerritsen Beach  3.0   1.0      0.04
# 4   New York  Brooklyn  1053053.0  Gerritsen Beach  3.0   1.0      0.04
# 9   New York  Brooklyn  1567742.0  Gerritsen Beach  3.0   2.0      0.04
# 10  New York  Brooklyn   513483.0  Gerritsen Beach  4.0   4.0      0.07
# 15  New York  Brooklyn   116782.0  Gerritsen Beach  3.0   2.0      0.08
# 16  New York  Brooklyn   726042.0  Gerritsen Beach  3.0   2.0      0.05
# 19  New York  Brooklyn  1309064.0  Gerritsen Beach  2.0   1.0      0.04
# 20  New York  Brooklyn   919169.0  Gerritsen Beach  4.0   2.0      0.04
# 21  New York  Brooklyn   585263.0  Gerritsen Beach  3.0   2.0      0.04
# 22  New York  Brooklyn   825381.0  Gerritsen Beach  4.0   3.0      0.04
# 23  New York  Brooklyn   672023.0  Gerritsen Beach  4.0   3.0      0.09
# 31  New York  Brooklyn   710495.0  Gerritsen Beach  2.0   2.0      0.04
# 32  New York  Brooklyn   541756.0  Gerritsen Beach  3.0   2.0      0.07
# 36  New York  Brooklyn  1285176.0  Gerritsen Beach  3.0   1.0      0.04
# 37  New York  Brooklyn   539111.0  Gerritsen Beach  4.0   4.0      0.05
# 39  New York  Brooklyn   751047.0  Gerritsen Beach  6.0   2.0      0.06
# 41  New York  Brooklyn   912460.0  Gerritsen Beach  4.0   2.0      0.04
# 42  New York  Brooklyn     9988.0  Gerritsen Beach  6.0   4.0      0.11
#
#     house_size      price  ranking zip_code  brokered_by    status  \
# 1        980.0   659000.0        1    11229      84536.0  for_sale
# 2       2352.0   938000.0        1    11229      81944.0  for_sale
# 3       1224.0   748000.0        1    11229      81286.0  for_sale
# 4       1000.0   538000.0        1    11229      76342.0  for_sale
# 9       1216.0   678000.0        1    11229      34944.0  for_sale
# 10      2400.0  2488000.0        1    11229      81944.0  for_sale
# 15      1047.0   699999.0        1    11229      81286.0  for_sale
# 16      1092.0   699999.0        1    11229      81286.0  for_sale
# 19       656.0   535000.0        1    11229      48297.0  for_sale
# 20      1360.0   689000.0        1    11229      96696.0  for_sale
# 21      1683.0   749000.0        1    11229      61044.0  for_sale
# 22      1292.0   998000.0        1    11229      81944.0  for_sale
# 23      2776.0  2250000.0        1    11229      30324.0  for_sale
# 31      1608.0   788000.0        1    11229      34944.0  for_sale
# 32      1400.0  1300000.0        1    11229      13691.0  for_sale
# 36      1280.0   499000.0        1    11229      28828.0  for_sale
# 37      2487.0  1288000.0        1    11229      86501.0  for_sale
# 39      2892.0  1658800.0        1    11229      30652.0  for_sale
# 41      1512.0   675000.0        1    11229       7844.0  for_sale
# 42      4185.0   989000.0        1    11229      81716.0  for_sale
#
#    prev_sold_date
# 1      2014-10-01
# 2      2021-07-07
# 3      2011-01-24
# 4      1996-12-16
# 9      2011-07-26
# 10     2007-10-25
# 15     2016-09-09
# 16     1997-04-04
# 19          other
# 20     2001-03-23
# 21          other
# 22     2016-01-13
# 23          other
# 31          other
# 32          other
# 36     2000-08-08
# 37          other
# 39     2019-11-12
# 41          other
# 42          other
